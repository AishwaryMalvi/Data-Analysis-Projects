# %% [markdown]
# Restaurant Sales Dataset
# Here,
#
# We have the sales data of a restaurant company from different cities (countries).
#
# This data is available in Excel file format. We are going to analyze and visualize this data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\Dell\Documents\Data Analysis Projects\Sales Data Analysis\Sales-Data-Analysis.xlsx")

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10453  2022-11-07 00:00:00           Beverages
# 3           NaN      10454  2022-11-07 00:00:00       Sides & Other
# 4           NaN      10455  2022-11-08 00:00:00             Burgers
# ..          ...        ...                  ...                 ...
# 250         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 251         NaN      10710  2022-12-29 00:00:00             Burgers
# 252         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 253         NaN      10712  2022-12-29 00:00:00               Fries
# 254         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8  \
# 0        Price    Quantity  Purchase Type  Payment Method             Manager
# 1         3.49  573.065903        Online        Gift Card    Tom      Jackson
# 2         2.95  745.762712        Online        Gift Card         Pablo Perez
# 3         4.99  200.400802      In-store        Gift Card       Joao    Silva
# 4        12.99  569.668976      In-store      Credit Card       Walter Muller
# ..         ...         ...            ...             ...                 ...
# 250       4.99  200.400802    Drive-thru        Gift Card       Walter Muller
# 251      12.99  754.426482    Drive-thru        Gift Card       Walter Muller
# 252       9.95  281.407035    Drive-thru        Gift Card       Walter Muller
# 253       3.49  630.372493    Drive-thru        Gift Card       Walter Muller
# 254       2.95  677.966102    Drive-thru        Gift Card       Walter Muller
#
#     Unnamed: 9
# 0         City
# 1       London
# 2       Madrid
# 3       Lisbon
# 4       Berlin
# ..         ...
# 250     Berlin
# 251     Berlin
# 252     Berlin
# 253     Berlin
# 254     Berlin
#
# [255 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    object
#  2   Unnamed: 2  255 non-null    object
#  3   Unnamed: 3  255 non-null    object
#  4   Unnamed: 4  255 non-null    object
#  5   Unnamed: 5  255 non-null    object
#  6   Unnamed: 6  255 non-null    object
#  7   Unnamed: 7  255 non-null    object
#  8   Unnamed: 8  255 non-null    object
#  9   Unnamed: 9  255 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.1+ KB

# %%
data.drop(columns='Unnamed: 0', inplace =True)

# %%
data.head()
# Out:
#   Unnamed: 1           Unnamed: 2     Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0   Order ID                 Date        Product      Price    Quantity
# 1      10452  2022-11-07 00:00:00          Fries       3.49  573.065903
# 2      10453  2022-11-07 00:00:00      Beverages       2.95  745.762712
# 3      10454  2022-11-07 00:00:00  Sides & Other       4.99  200.400802
# 4      10455  2022-11-08 00:00:00        Burgers      12.99  569.668976
#
#       Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Purchase Type  Payment Method             Manager       City
# 1        Online        Gift Card    Tom      Jackson     London
# 2        Online        Gift Card         Pablo Perez     Madrid
# 3      In-store        Gift Card       Joao    Silva     Lisbon
# 4      In-store      Credit Card       Walter Muller     Berlin

# %%
data.loc[0]
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: object

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data.columns = data.iloc[0]

# %%
data.drop(0, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %%
data.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 14

# %%
data['Manager'] = data['Manager'].str.strip().str.replace(r'\s+',' ', regex=True)

# %%
data.head()
# Out:
# 0 Order ID                 Date             Product  Price    Quantity  \
# 1    10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2    10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 3    10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 4    10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 5    10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0 Purchase Type Payment Method        Manager    City
# 1       Online       Gift Card    Tom Jackson  London
# 2       Online       Gift Card    Pablo Perez  Madrid
# 3     In-store       Gift Card     Joao Silva  Lisbon
# 4     In-store     Credit Card  Walter Muller  Berlin
# 5     In-store     Credit Card  Walter Muller  Berlin

# %%
data['Manager'].unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.describe()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3652\3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date  Product   Price    Quantity  \
# count        254                  254      254  254.00  254.000000
# unique       254                   53        5    7.00   29.000000
# top        10452  2022-12-03 00:00:00  Burgers   12.99  200.400802
# freq           1                    5       52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# freq             107            120           75      75

# %%
data[data.duplicated()]                    # to show all the duplicate records
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]                    # to check the duplicate records
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.describe()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3652\3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date  Product   Price    Quantity  \
# count        254                  254      254  254.00  254.000000
# unique       254                   53        5    7.00   29.000000
# top        10452  2022-12-03 00:00:00  Burgers   12.99  200.400802
# freq           1                    5       52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# freq             107            120           75      75

# %%
data[data['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data[data['Order ID'] == 10483]
# Out:
# 0  Order ID                 Date    Product Price    Quantity Purchase Type  \
# 61    10483  2022-11-13 00:00:00  Beverages  2.95  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 61    Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'] == 10484]
# Out:
# 0  Order ID                 Date        Product Price    Quantity  \
# 62    10484  2022-11-13 00:00:00  Sides & Other  4.99  200.400802
#
# 0  Purchase Type Payment Method     Manager    City
# 62     In-store     Credit Card  Joao Silva  Lisbon

# %%
data[data['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %%
data.Quantity = data.Quantity.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 18.0+ KB

# %%
data.Quantity = data.Quantity.round()

# %%
data.Quantity
# Out:
# 1      573.0
# 2      746.0
# 3      200.0
# 4      570.0
# 5      201.0
#        ...
# 250    200.0
# 251    754.0
# 252    281.0
# 253    630.0
# 254    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
data.Quantity = data.Quantity.astype(int)

# %%
data['Quantity']
# Out:
# 1      573
# 2      746
# 3      200
# 4      570
# 5      201
#       ...
# 250    200
# 251    754
# 252    281
# 253    630
# 254    678
# Name: Quantity, Length: 254, dtype: int32

# %%
data['Order Id'] = data['Order ID'].astype(int)
data['Price'] = data['Price'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    int32
#  4   Quantity        254 non-null    int32
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   Order Id        254 non-null    int32
# dtypes: int32(3), object(7)
# memory usage: 17.0+ KB

# %%
data.Date= pd.to_datetime(data.Date)

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    int32
#  4   Quantity        254 non-null    int32
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   Order Id        254 non-null    int32
# dtypes: datetime64[ns](1), int32(3), object(6)
# memory usage: 17.0+ KB

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries      3       573       Online
# 2      10453 2022-11-07           Beverages      2       746       Online
# 3      10454 2022-11-07       Sides & Other      4       200     In-store
# 4      10455 2022-11-08             Burgers     12       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches      9       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other      4       200   Drive-thru
# 251    10710 2022-12-29             Burgers     12       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches      9       281   Drive-thru
# 253    10712 2022-12-29               Fries      3       630   Drive-thru
# 254    10713 2022-12-29           Beverages      2       678   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id
# 1        Gift Card    Tom Jackson  London     10452
# 2        Gift Card    Pablo Perez  Madrid     10453
# 3        Gift Card     Joao Silva  Lisbon     10454
# 4      Credit Card  Walter Muller  Berlin     10455
# 5      Credit Card  Walter Muller  Berlin     10456
# ..             ...            ...     ...       ...
# 250      Gift Card  Walter Muller  Berlin     10709
# 251      Gift Card  Walter Muller  Berlin     10710
# 252      Gift Card  Walter Muller  Berlin     10711
# 253      Gift Card  Walter Muller  Berlin     10712
# 254      Gift Card  Walter Muller  Berlin     10713
#
# [254 rows x 10 columns]

# %%
## Most Preferred Payment Method

data['Payment Method'].unique()
# Out:
# array([' Gift Card', ' Credit Card', ' Cash'], dtype=object)

# %%
data['Payment Method'].nunique()
# Out:
# 3

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment Method'>

# %%
## Most Selling Product ?
## By Quantity
## By Revenue

data.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Beverages             34988
# Burgers               29018
# Chicken Sandwiches    11133
# Fries                 32023
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
most_quantity = data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quantity
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
type(most_quantity)
# Out:
# pandas.core.series.Series

# %%
most_qunatity = most_quantity.reset_index()
most_quantity
# Out:
# Product
# Beverages             34988
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int32

# %%
type(most_quantity)
# Out:
# pandas.core.series.Series

# %%
most_quantity = most_quantity.reset_index()

plt.figure(figsize = (9,4))
plt.bar(most_quantity['Product'], most_quantity['Quantity'], color = ['red', 'black', 'green', 'yellow', 'cyan'], width=0.4)
plt.title("Most Selling Product - By Quantity")
plt.xlabel("Product")
plt.ylabel("Quantity")
plt.show()

# %%
data['Revenue'] = data['Price'] * data['Quantity']

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries      3       573       Online
# 2      10453 2022-11-07           Beverages      2       746       Online
# 3      10454 2022-11-07       Sides & Other      4       200     In-store
# 4      10455 2022-11-08             Burgers     12       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches      9       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other      4       200   Drive-thru
# 251    10710 2022-12-29             Burgers     12       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches      9       281   Drive-thru
# 253    10712 2022-12-29               Fries      3       630   Drive-thru
# 254    10713 2022-12-29           Beverages      2       678   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id  Revenue
# 1        Gift Card    Tom Jackson  London     10452     1719
# 2        Gift Card    Pablo Perez  Madrid     10453     1492
# 3        Gift Card     Joao Silva  Lisbon     10454      800
# 4      Credit Card  Walter Muller  Berlin     10455     6840
# 5      Credit Card  Walter Muller  Berlin     10456     1809
# ..             ...            ...     ...       ...      ...
# 250      Gift Card  Walter Muller  Berlin     10709      800
# 251      Gift Card  Walter Muller  Berlin     10710     9048
# 252      Gift Card  Walter Muller  Berlin     10711     2529
# 253      Gift Card  Walter Muller  Berlin     10712     1890
# 254      Gift Card  Walter Muller  Berlin     10713     1356
#
# [254 rows x 11 columns]

# %%
data.groupby('Product')['Revenue'].sum().sort_values(ascending = False)
# Out:
# Product
# Burgers               348216
# Fries                 109929
# Chicken Sandwiches    104217
# Beverages              69976
# Sides & Other          39200
# Name: Revenue, dtype: int32

# %%
most_revenue = data.groupby('Product')['Revenue'].sum().sort_values(ascending = False)
most_revenue
# Out:
# Product
# Burgers               348216
# Fries                 109929
# Chicken Sandwiches    104217
# Beverages              69976
# Sides & Other          39200
# Name: Revenue, dtype: int32

# %%
most_revenue = most_revenue.reset_index()
most_revenue
# Out:
#               Product  Revenue
# 0             Burgers   348216
# 1               Fries   109929
# 2  Chicken Sandwiches   104217
# 3           Beverages    69976
# 4       Sides & Other    39200

# %%
plt.figure(figsize=(9, 4))
plt.bar(most_revenue['Product'], most_revenue['Revenue'], color = ['green', 'red', 'black', 'yellow', 'cyan'], width = 0.3);
plt.title("Most Selling Product - By Revenue")       # setting the title       
plt.xlabel("Product")                                # setting the x-axis label
plt.ylabel("Revenue");                               # setting the y-axis label

# %%
#### Q.3) Which city had maximum revenue
##### or
##### Which Manager earned maximum revenue

data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data.City.unique()
# Out:
# array(['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris'], dtype=object)

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    211853
# London    183443
# Madrid    118706
# Berlin     88071
# Paris      69465
# Name: Revenue, dtype: int32

# %%
data.Manager.unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 5

# %%
data.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       211853
# Tom Jackson      183443
# Pablo Perez      118706
# Walter Muller     88071
# Remy Monet        69465
# Name: Revenue, dtype: int32

# %%
## Date wise revenue

data.plot('Date', 'Revenue', color='red', linewidth=2, figsize=(9,4)) 
plt.title("Date wise Revenue")                        # setting the title
plt.xlabel("Date")                                    # setting the x-axis label
plt.ylabel("Revenue")                                 # setting the y-axis label
plt.show()

# %%
## Average Revenue

data['Revenue'].mean()
# Out:
# 2643.850393700787

# %%
## Average Revenue of November & December month

data['Month'] = data['Date'].dt.month

# %%
data
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries      3       573       Online
# 2      10453 2022-11-07           Beverages      2       746       Online
# 3      10454 2022-11-07       Sides & Other      4       200     In-store
# 4      10455 2022-11-08             Burgers     12       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches      9       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other      4       200   Drive-thru
# 251    10710 2022-12-29             Burgers     12       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches      9       281   Drive-thru
# 253    10712 2022-12-29               Fries      3       630   Drive-thru
# 254    10713 2022-12-29           Beverages      2       678   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id  Revenue  Month
# 1        Gift Card    Tom Jackson  London     10452     1719     11
# 2        Gift Card    Pablo Perez  Madrid     10453     1492     11
# 3        Gift Card     Joao Silva  Lisbon     10454      800     11
# 4      Credit Card  Walter Muller  Berlin     10455     6840     11
# 5      Credit Card  Walter Muller  Berlin     10456     1809     11
# ..             ...            ...     ...       ...      ...    ...
# 250      Gift Card  Walter Muller  Berlin     10709      800     12
# 251      Gift Card  Walter Muller  Berlin     10710     9048     12
# 252      Gift Card  Walter Muller  Berlin     10711     2529     12
# 253      Gift Card  Walter Muller  Berlin     10712     1890     12
# 254      Gift Card  Walter Muller  Berlin     10713     1356     12
#
# [254 rows x 12 columns]

# %%
m11 = data[data['Month'] == 11]
m11
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries      3       573       Online
# 2      10453 2022-11-07           Beverages      2       746       Online
# 3      10454 2022-11-07       Sides & Other      4       200     In-store
# 4      10455 2022-11-08             Burgers     12       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches      9       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 109    10568 2022-11-30           Beverages      2       678       Online
# 110    10569 2022-11-30       Sides & Other      4       200       Online
# 128    10537 2022-11-24               Fries      3       630   Drive-thru
# 129    10538 2022-11-24           Beverages      2       746   Drive-thru
# 130    10539 2022-11-24       Sides & Other      4       200   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id  Revenue  Month
# 1        Gift Card    Tom Jackson  London     10452     1719     11
# 2        Gift Card    Pablo Perez  Madrid     10453     1492     11
# 3        Gift Card     Joao Silva  Lisbon     10454      800     11
# 4      Credit Card  Walter Muller  Berlin     10455     6840     11
# 5      Credit Card  Walter Muller  Berlin     10456     1809     11
# ..             ...            ...     ...       ...      ...    ...
# 109    Credit Card    Tom Jackson  London     10568     1356     11
# 110    Credit Card    Tom Jackson  London     10569      800     11
# 128    Credit Card    Pablo Perez  Madrid     10537     1890     11
# 129    Credit Card    Pablo Perez  Madrid     10538     1492     11
# 130    Credit Card    Pablo Perez  Madrid     10539      800     11
#
# [113 rows x 12 columns]

# %%
m11.Revenue.mean()
# Out:
# 2568.3274336283184

# %%
m12 = data[data.Month == 12]
m12
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111    10570 2022-12-01             Burgers     12       493       Online
# 112    10571 2022-12-01  Chicken Sandwiches      9       201       Online
# 113    10572 2022-12-01               Fries      3       573       Online
# 114    10573 2022-12-01           Beverages      2       678       Online
# 115    10574 2022-12-01       Sides & Other      4       200       Online
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other      4       200   Drive-thru
# 251    10710 2022-12-29             Burgers     12       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches      9       281   Drive-thru
# 253    10712 2022-12-29               Fries      3       630   Drive-thru
# 254    10713 2022-12-29           Beverages      2       678   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id  Revenue  Month
# 111    Credit Card    Tom Jackson  London     10570     5916     12
# 112    Credit Card    Tom Jackson  London     10571     1809     12
# 113    Credit Card     Remy Monet   Paris     10572     1719     12
# 114    Credit Card     Remy Monet   Paris     10573     1356     12
# 115    Credit Card     Remy Monet   Paris     10574      800     12
# ..             ...            ...     ...       ...      ...    ...
# 250      Gift Card  Walter Muller  Berlin     10709      800     12
# 251      Gift Card  Walter Muller  Berlin     10710     9048     12
# 252      Gift Card  Walter Muller  Berlin     10711     2529     12
# 253      Gift Card  Walter Muller  Berlin     10712     1890     12
# 254      Gift Card  Walter Muller  Berlin     10713     1356     12
#
# [141 rows x 12 columns]

# %%
m12.Revenue.mean()
# Out:
# 2704.375886524823

# %%
## Standard Deviation of Revenue and Quantity

data['Quantity'].std()
# Out:
# 214.97943096363838

# %%
data['Revenue'].std()
# Out:
# 2335.33689482098

# %%
## Variance of Revenue and Quantity

data['Quantity'].var()
# Out:
# 46216.155737449764

# %%
data['Revenue'].var()
# Out:
# 5453798.412312097

# %%
## Is revenue increasing or decreasing over time

m11 = data[data['Month'] == 11]
m11
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1      10452 2022-11-07               Fries      3       573       Online
# 2      10453 2022-11-07           Beverages      2       746       Online
# 3      10454 2022-11-07       Sides & Other      4       200     In-store
# 4      10455 2022-11-08             Burgers     12       570     In-store
# 5      10456 2022-11-08  Chicken Sandwiches      9       201     In-store
# ..       ...        ...                 ...    ...       ...           ...
# 109    10568 2022-11-30           Beverages      2       678       Online
# 110    10569 2022-11-30       Sides & Other      4       200       Online
# 128    10537 2022-11-24               Fries      3       630   Drive-thru
# 129    10538 2022-11-24           Beverages      2       746   Drive-thru
# 130    10539 2022-11-24       Sides & Other      4       200   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id  Revenue  Month
# 1        Gift Card    Tom Jackson  London     10452     1719     11
# 2        Gift Card    Pablo Perez  Madrid     10453     1492     11
# 3        Gift Card     Joao Silva  Lisbon     10454      800     11
# 4      Credit Card  Walter Muller  Berlin     10455     6840     11
# 5      Credit Card  Walter Muller  Berlin     10456     1809     11
# ..             ...            ...     ...       ...      ...    ...
# 109    Credit Card    Tom Jackson  London     10568     1356     11
# 110    Credit Card    Tom Jackson  London     10569      800     11
# 128    Credit Card    Pablo Perez  Madrid     10537     1890     11
# 129    Credit Card    Pablo Perez  Madrid     10538     1492     11
# 130    Credit Card    Pablo Perez  Madrid     10539      800     11
#
# [113 rows x 12 columns]

# %%
m11['Revenue'].sum()
# Out:
# 290221

# %%
m12 = data[data.Month == 12]
m12
# Out:
# 0   Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111    10570 2022-12-01             Burgers     12       493       Online
# 112    10571 2022-12-01  Chicken Sandwiches      9       201       Online
# 113    10572 2022-12-01               Fries      3       573       Online
# 114    10573 2022-12-01           Beverages      2       678       Online
# 115    10574 2022-12-01       Sides & Other      4       200       Online
# ..       ...        ...                 ...    ...       ...           ...
# 250    10709 2022-12-28       Sides & Other      4       200   Drive-thru
# 251    10710 2022-12-29             Burgers     12       754   Drive-thru
# 252    10711 2022-12-29  Chicken Sandwiches      9       281   Drive-thru
# 253    10712 2022-12-29               Fries      3       630   Drive-thru
# 254    10713 2022-12-29           Beverages      2       678   Drive-thru
#
# 0   Payment Method        Manager    City  Order Id  Revenue  Month
# 111    Credit Card    Tom Jackson  London     10570     5916     12
# 112    Credit Card    Tom Jackson  London     10571     1809     12
# 113    Credit Card     Remy Monet   Paris     10572     1719     12
# 114    Credit Card     Remy Monet   Paris     10573     1356     12
# 115    Credit Card     Remy Monet   Paris     10574      800     12
# ..             ...            ...     ...       ...      ...    ...
# 250      Gift Card  Walter Muller  Berlin     10709      800     12
# 251      Gift Card  Walter Muller  Berlin     10710     9048     12
# 252      Gift Card  Walter Muller  Berlin     10711     2529     12
# 253      Gift Card  Walter Muller  Berlin     10712     1890     12
# 254      Gift Card  Walter Muller  Berlin     10713     1356     12
#
# [141 rows x 12 columns]

# %%
m12.Revenue.sum()
# Out:
# 381317

# %%
data.groupby('Product')[['Quantity', 'Revenue']].agg({'Quantity':'mean', 'Revenue':'mean'})
# Out:
# 0                     Quantity      Revenue
# Product
# Beverages           699.760000  1399.520000
# Burgers             558.038462  6696.461538
# Chicken Sandwiches  214.096154  2004.173077
# Fries               627.901961  2155.470588
# Sides & Other       200.000000   800.000000
